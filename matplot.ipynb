# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,20,1000)

# %%
y= np.sin(x)+0.2*x

# %%
plt.xlabel("input")
plt.ylabel("output")
plt.title("My plot")
plt.plot(x,y)

# %%
a=np.random.randn(300,2)
plt.scatter(a[:,0],a[:,1])

# %%
x=np.random.randn(200,2)
x[:50]+=3
y=np.zeros(200)
y[:50]=1
plt.scatter(x[:,0],x[:,1],c=y)

# %%
x=np.random.randn(10000)

# %%
plt.hist(x)
# Out:
# (array([  17.,  118.,  624., 1779., 2955., 2571., 1407.,  451.,   71.,
#            7.]),
#  array([-3.72560532, -2.95975889, -2.19391245, -1.42806602, -0.66221959,
#          0.10362685,  0.86947328,  1.63531971,  2.40116614,  3.16701258,
#          3.93285901]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(x,bins=50)
# Out:
# (array([  1.,   0.,   3.,   7.,   6.,   6.,  14.,  19.,  34.,  45.,  61.,
#          87., 120., 168., 188., 238., 309., 354., 407., 471., 542., 600.,
#         599., 610., 604., 544., 560., 528., 520., 419., 383., 330., 314.,
#         203., 177., 154., 110.,  92.,  55.,  40.,  31.,  18.,  13.,   5.,
#           4.,   3.,   2.,   0.,   1.,   1.]),
#  array([-3.72560532, -3.57243603, -3.41926675, -3.26609746, -3.11292817,
#         -2.95975889, -2.8065896 , -2.65342031, -2.50025103, -2.34708174,
#         -2.19391245, -2.04074317, -1.88757388, -1.73440459, -1.58123531,
#         -1.42806602, -1.27489673, -1.12172745, -0.96855816, -0.81538887,
#         -0.66221959, -0.5090503 , -0.35588101, -0.20271173, -0.04954244,
#          0.10362685,  0.25679613,  0.40996542,  0.56313471,  0.71630399,
#          0.86947328,  1.02264256,  1.17581185,  1.32898114,  1.48215042,
#          1.63531971,  1.788489  ,  1.94165828,  2.09482757,  2.24799686,
#          2.40116614,  2.55433543,  2.70750472,  2.860674  ,  3.01384329,
#          3.16701258,  3.32018186,  3.47335115,  3.62652044,  3.77968972,
#          3.93285901]),
#  <a list of 50 Patch objects>)

# %%
x=np.random.rand(10000)
plt.hist(x,bins=50)
# Out:
# (array([209., 225., 219., 190., 208., 232., 222., 199., 192., 199., 211.,
#         191., 205., 204., 191., 176., 191., 189., 198., 195., 181., 167.,
#         207., 206., 183., 192., 220., 179., 200., 200., 209., 214., 217.,
#         187., 196., 181., 200., 207., 215., 203., 202., 223., 193., 176.,
#         188., 201., 194., 218., 208., 187.]),
#  array([4.34122584e-05, 2.00401854e-02, 4.00369586e-02, 6.00337317e-02,
#         8.00305049e-02, 1.00027278e-01, 1.20024051e-01, 1.40020824e-01,
#         1.60017597e-01, 1.80014371e-01, 2.00011144e-01, 2.20007917e-01,
#         2.40004690e-01, 2.60001463e-01, 2.79998236e-01, 2.99995009e-01,
#         3.19991783e-01, 3.39988556e-01, 3.59985329e-01, 3.79982102e-01,
#         3.99978875e-01, 4.19975648e-01, 4.39972422e-01, 4.59969195e-01,
#         4.79965968e-01, 4.99962741e-01, 5.19959514e-01, 5.39956287e-01,
#         5.59953060e-01, 5.79949834e-01, 5.99946607e-01, 6.19943380e-01,
#         6.39940153e-01, 6.59936926e-01, 6.79933699e-01, 6.99930472e-01,
#         7.19927246e-01, 7.39924019e-01, 7.59920792e-01, 7.79917565e-01,
#         7.99914338e-01, 8.19911111e-01, 8.39907885e-01, 8.59904658e-01,
#         8.79901431e-01, 8.99898204e-01, 9.19894977e-01, 9.39891750e-01,
#         9.59888523e-01, 9.79885297e-01, 9.99882070e-01]),
#  <a list of 50 Patch objects>)

# %%
from PIL import Image

# %%
im =Image.open("C:\\Users\\shouri\\Pictures\\fujitsu-siemens-amilo-a1650g-veikiantis.jpg")

# %%
type(im)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
arr=np.array(im)

# %%
arr.shape
# Out:
# (900, 1200, 3)

# %%
plt.imshow(arr)

# %%
gray=arr.mean(axis=2)

# %%
plt.imshow(gray,cmap="gray")
